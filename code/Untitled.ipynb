# %%
import pandas as pd

# %%
df1 = pd.read_csv('../data/drivers_updated.csv')
df2 = pd.read_csv('../data/fastest_laps_updated.csv')
df3 = pd.read_csv('../data/teams_updated.csv')
df4 = pd.read_csv('../data/winners.csv')

# %% [markdown]
# # Objetivos del análisis
# ### Comparativa vueltas rapidas entre años
# ### Comprobación dominancia de escuderias por ptos entre temporadas
# ### Nacionalidades predominantes en la f1

# %%
df1
# Out:
#      Pos                Driver Nationality                  Car   PTS  year  \
# 0      1         Nino  Farina          ITA           Alfa Romeo  30.0  1950
# 1      2  Juan Manuel  Fangio          ARG           Alfa Romeo  27.0  1950
# 2      3       Luigi  Fagioli          ITA           Alfa Romeo  24.0  1950
# 3      4         Louis Rosier          FRA          Talbot-Lago  13.0  1950
# 4      5      Alberto  Ascari          ITA              Ferrari  11.0  1950
# ...   ..                   ...         ...                  ...   ...   ...
# 1656  17     Kevin  Magnussen          DEN         Haas Ferrari   1.0  2024
# 1657  18        Pierre  Gasly          FRA       Alpine Renault   1.0  2024
# 1658  19         Zhou  Guanyu          CHN  Kick Sauber Ferrari   0.0  2024
# 1659  20     Valtteri  Bottas          FIN  Kick Sauber Ferrari   0.0  2024
# 1660  21      Logan  Sargeant          USA    Williams Mercedes   0.0  2024
#
#      Code
# 0     FAR
# 1     FAN
# 2     FAG
# 3     ROS
# 4     ASC
# ...   ...
# 1656  MAG
# 1657  GAS
# 1658  ZHO
# 1659  BOT
# 1660  SAR
#
# [1661 rows x 7 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1661 entries, 0 to 1660
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pos          1661 non-null   object
#  1   driver       1661 non-null   object
#  2   nationality  1661 non-null   object
#  3   car          1651 non-null   object
#  4   pts          1661 non-null   float64
#  5   year         1661 non-null   int64
#  6   code         1661 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 91.0+ KB

# %%
df1.isna().sum()
# Out:
# Pos             0
# Driver          0
# Nationality     0
# Car            11
# PTS             0
# year            0
# Code            0
# dtype: int64

# %%
df1.columns = df1.columns.str.lower()

# %%
df1[df1.car.isna()]
# Out:
#     pos               driver nationality  car   pts  year code
# 16   13     Dorino Serafini          ITA  NaN   3.0  1950  SER
# 17   13  Philippe Etancelin          FRA  NaN   3.0  1950  ETA
# 21   20      Eugene Chaboud          FRA  NaN   1.0  1950  CHA
# 35   12        Louis Rosier          FRA  NaN   3.0  1951  ROS
# 53   13         Ken Wharton          GBR  NaN   3.0  1952  WHA
# 309  18     Masten  Gregory          USA  NaN   0.0  1963  GRE
# 314  18      Mike  Hailwood          GBR  NaN   0.0  1963  HAI
# 446  13    Richard  Attwood          GBR  NaN   3.0  1969  ATT
# 478   2    Ronnie  Peterson          SWE  NaN  33.0  1971  PET
# 492  16       Mark  Donohue          USA  NaN   4.0  1971  DON
# 493  16    Henri  Pescarolo          FRA  NaN   4.0  1971  PES

# %%
df1[df1.year==1950].sort_values(by='car')
# Out:
#    pos                   driver nationality                       car   pts  \
# 0    1            Nino  Farina          ITA                Alfa Romeo  30.0
# 1    2     Juan Manuel  Fangio          ARG                Alfa Romeo  27.0
# 2    3          Luigi  Fagioli          ITA                Alfa Romeo  24.0
# 6    7           Bill  Holland          USA         Deidt Offenhauser   6.0
# 10   9              Mauri Rose          USA         Deidt Offenhauser   4.0
# 19  20       Tony Bettenhausen          USA         Deidt Offenhauser   1.0
# 16  13         Dorino Serafini          ITA                   Ferrari   3.0
# 4    5         Alberto  Ascari          ITA                   Ferrari  11.0
# 11   9         Peter Whitehead          GBR                   Ferrari   4.0
# 14  13             Cecil Green          USA  Kurtis Kraft Offenhauser   3.0
# 20  20           Joie Chitwood          USA  Kurtis Kraft Offenhauser   1.0
# 5    6         Johnnie Parsons          USA  Kurtis Kraft Offenhauser   9.0
# 7    8            Prince  Bira          THA                  Maserati   5.0
# 8    9             Reg Parnell          GBR                  Maserati   4.0
# 9    9            Louis Chiron          MON                  Maserati   4.0
# 18  19          Felice Bonetto          ITA           Maserati Milano   2.0
# 15  13           Robert Manzon          FRA             Simca-Gordini   3.0
# 12  13  Yves Giraud  Cabantous          FRA               Talbot-Lago   3.0
# 13  13          Raymond Sommer          FRA               Talbot-Lago   3.0
# 3    4            Louis Rosier          FRA               Talbot-Lago  13.0
# 17  13      Philippe Etancelin          FRA                       NaN   3.0
# 21  20          Eugene Chaboud          FRA                       NaN   1.0
#
#     year code
# 0   1950  FAR
# 1   1950  FAN
# 2   1950  FAG
# 6   1950  HOL
# 10  1950  ROS
# 19  1950  BET
# 16  1950  SER
# 4   1950  ASC
# 11  1950  WHI
# 14  1950  GRE
# 20  1950  CHI
# 5   1950  PAR
# 7   1950  BIR
# 8   1950  PAR
# 9   1950  CHI
# 18  1950  BON
# 15  1950  MAN
# 12  1950  CAB
# 13  1950  SOM
# 3   1950  ROS
# 17  1950  ETA
# 21  1950  CHA

# %%
df1.iloc[16, 3] = 'Ferrari'  # lo de corchete del iloc es: el primmer numero index, segundo numero columna

# %%
df1[df1.year==1950].sort_values(by='car').reset_index()
# Out:
#     index pos                   driver nationality                       car  \
# 0       0   1            Nino  Farina          ITA                Alfa Romeo
# 1       1   2     Juan Manuel  Fangio          ARG                Alfa Romeo
# 2       2   3          Luigi  Fagioli          ITA                Alfa Romeo
# 3       6   7           Bill  Holland          USA         Deidt Offenhauser
# 4      10   9              Mauri Rose          USA         Deidt Offenhauser
# 5      19  20       Tony Bettenhausen          USA         Deidt Offenhauser
# 6      16  13         Dorino Serafini          ITA                   Ferrari
# 7       4   5         Alberto  Ascari          ITA                   Ferrari
# 8      11   9         Peter Whitehead          GBR                   Ferrari
# 9      14  13             Cecil Green          USA  Kurtis Kraft Offenhauser
# 10     20  20           Joie Chitwood          USA  Kurtis Kraft Offenhauser
# 11      5   6         Johnnie Parsons          USA  Kurtis Kraft Offenhauser
# 12      7   8            Prince  Bira          THA                  Maserati
# 13      8   9             Reg Parnell          GBR                  Maserati
# 14      9   9            Louis Chiron          MON                  Maserati
# 15     18  19          Felice Bonetto          ITA           Maserati Milano
# 16     15  13           Robert Manzon          FRA             Simca-Gordini
# 17     12  13  Yves Giraud  Cabantous          FRA               Talbot-Lago
# 18     13  13          Raymond Sommer          FRA               Talbot-Lago
# 19      3   4            Louis Rosier          FRA               Talbot-Lago
# 20     17  13      Philippe Etancelin          FRA                       NaN
# 21     21  20          Eugene Chaboud          FRA                       NaN
#
#      pts  year code
# 0   30.0  1950  FAR
# 1   27.0  1950  FAN
# 2   24.0  1950  FAG
# 3    6.0  1950  HOL
# 4    4.0  1950  ROS
# 5    1.0  1950  BET
# 6    3.0  1950  SER
# 7   11.0  1950  ASC
# 8    4.0  1950  WHI
# 9    3.0  1950  GRE
# 10   1.0  1950  CHI
# 11   9.0  1950  PAR
# 12   5.0  1950  BIR
# 13   4.0  1950  PAR
# 14   4.0  1950  CHI
# 15   2.0  1950  BON
# 16   3.0  1950  MAN
# 17   3.0  1950  CAB
# 18   3.0  1950  SOM
# 19  13.0  1950  ROS
# 20   3.0  1950  ETA
# 21   1.0  1950  CHA

# %%
df1[df1.driver.str.contains('maurice', case=False, na=False)]
# Out:
#     pos                driver nationality            car   pts  year code
# 59   16  Maurice Trintignant          FRA        Gordini   2.0  1952  TRI
# 74   11  Maurice Trintignant          FRA        Gordini   4.0  1953  TRI
# 85    4  Maurice Trintignant          FRA        Ferrari  17.0  1954  TRI
# 111   4  Maurice Trintignant          FRA        Ferrari  11.3  1955  TRI
# 172  12  Maurice Trintignant          FRA        Ferrari   5.0  1957  TRI
# 188   7  Maurice Trintignant          FRA  Cooper Climax  12.0  1958  TRI
# 207   5  Maurice Trintignant          FRA  Cooper Climax  19.0  1959  TRI
# 303  18  Maurice Trintignant          FRA            BRM   0.0  1963  TRI
# 347  16  Maurice Trintignant          FRA            BRM   2.0  1964  TRI

# %%
def buscar_nombre_df1(columna, nombre):

    return df1[df1[columna].str.contains(nombre, case=False, na=False)]

# %%
buscar_nombre_df1('car', 'fer')
# Out:
#      pos                   driver nationality                  car   pts  \
# 4      5         Alberto  Ascari          ITA              Ferrari  11.0
# 11     9         Peter Whitehead          GBR              Ferrari   4.0
# 16    13         Dorino Serafini          ITA              Ferrari   3.0
# 23     2         Alberto  Ascari          ITA              Ferrari  25.0
# 24     3  Jose Froilan  Gonzalez          ARG              Ferrari  24.0
# ...   ..                      ...         ...                  ...   ...
# 1651  12         Oliver  Bearman          GBR              Ferrari   6.0
# 1652  13        Nico  Hulkenberg          GER         Haas Ferrari   6.0
# 1656  17        Kevin  Magnussen          DEN         Haas Ferrari   1.0
# 1658  19            Zhou  Guanyu          CHN  Kick Sauber Ferrari   0.0
# 1659  20        Valtteri  Bottas          FIN  Kick Sauber Ferrari   0.0
#
#       year code
# 4     1950  ASC
# 11    1950  WHI
# 16    1950  SER
# 23    1951  ASC
# 24    1951  GON
# ...    ...  ...
# 1651  2024  BEA
# 1652  2024  HUL
# 1656  2024  MAG
# 1658  2024  ZHO
# 1659  2024  BOT
#
# [294 rows x 7 columns]
